# %%
import os
from dotenv import load_dotenv
import json
import requests
import re
load_dotenv()
from pandas import json_normalize
import pandas as pd
import src.funciones_api as funcion
import matplotlib.pyplot as plot
import seaborn as sns
from seaborn import violinplot
import numpy as np
import plotly.express as px
import time

# %%
os.system('say -v Samantha calling first Api')
# Out:
# 0

# %%
import requests

api_key = os.getenv("Api_key")
url = "https://api.triathlon.org/v1/search/athletes?filters=athlete_gender,male|elite,true"

querystring = {"per_page":"100"}

headers = {"apikey": api_key}

response = requests.request("GET", url, headers=headers, params=querystring).json()
response
# Out:
# {'code': 200,
#  'status': 'success',
#  'current_page': 1,
#  'data': [{'athlete_id': 11143,
#    'athlete_title': 'Vincent Luis',
#    'athlete_slug': 'vincent_luis',
#    'athlete_first': 'Vincent',
#    'athlete_last': 'Luis',
#    'athlete_country_id': 166,
#    'athlete_gender': 'male',
#    'athlete_yob': '1989',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/vincent_luis_FRA.jpg',
#    'athlete_noc': 'FRA',
#    'athlete_country_name': 'France',
#    'athlete_country_isoa2': 'FR',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/11143/vincent_luis',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/fr.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/11143',
#    'athlete_categories': [42],
#    'points_list_ranking': 1,
#    '_highlightResult': {'athlete_title': {'value': 'Vincent Luis',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'FRA', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'France',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 11402,
#    'athlete_title': 'Mario Mola',
#    'athlete_slug': 'mario_mola',
#    'athlete_first': 'Mario',
#    'athlete_last': 'Mola',
#    'athlete_country_id': 270,
#    'athlete_gender': 'male',
#    'athlete_yob': '1990',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/mario_mola_ESP.jpg',
#    'athlete_noc': 'ESP',
#    'athlete_country_name': 'Spain',
#    'athlete_country_isoa2': 'ES',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/11402/mario_mola',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/es.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/11402',
#    'athlete_categories': [42, 539],
#    'points_list_ranking': 2,
#    '_highlightResult': {'athlete_title': {'value': 'Mario Mola',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'ESP', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Spain',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 29442,
#    'athlete_title': 'Fernando Alarza',
#    'athlete_slug': 'fernando_alarza',
#    'athlete_first': 'Fernando',
#    'athlete_last': 'Alarza',
#    'athlete_country_id': 270,
#    'athlete_gender': 'male',
#    'athlete_yob': '1991',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/fer_alarza_ESP.jpg',
#    'athlete_noc': 'ESP',
#    'athlete_country_name': 'Spain',
#    'athlete_country_isoa2': 'ES',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/29442/fernando_alarza',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/es.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/29442',
#    'athlete_categories': [42, 539],
#    'points_list_ranking': 3,
#    '_highlightResult': {'athlete_title': {'value': 'Fernando Alarza',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'ESP', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Spain',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 45915,
#    'athlete_title': 'Jacob Birtwhistle',
#    'athlete_slug': 'jacob_birtwhistle',
#    'athlete_first': 'Jacob',
#    'athlete_last': 'Birtwhistle',
#    'athlete_country_id': 111,
#    'athlete_gender': 'male',
#    'athlete_yob': '1995',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/jake_birtwhistle_AUS.jpg',
#    'athlete_noc': 'AUS',
#    'athlete_country_name': 'Australia',
#    'athlete_country_isoa2': 'AU',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/45915/jacob_birtwhistle',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/au.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/45915',
#    'athlete_categories': [42, 539],
#    'points_list_ranking': 4,
#    '_highlightResult': {'athlete_title': {'value': 'Jacob Birtwhistle',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'AUS', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Australia',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 49411,
#    'athlete_title': 'Tyler Mislawchuk',
#    'athlete_slug': 'tyler_mislawchuk',
#    'athlete_first': 'Tyler',
#    'athlete_last': 'Mislawchuk',
#    'athlete_country_id': 135,
#    'athlete_gender': 'male',
#    'athlete_yob': '1994',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/tyler_mislawchuk_can_elite1.jpg',
#    'athlete_noc': 'CAN',
#    'athlete_country_name': 'Canada',
#    'athlete_country_isoa2': 'CA',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/49411/tyler_mislawchuk',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/ca.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/49411',
#    'athlete_categories': [42],
#    'points_list_ranking': 5,
#    '_highlightResult': {'athlete_title': {'value': 'Tyler Mislawchuk',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'CAN', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Canada',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 40311,
#    'athlete_title': 'Marten Van Riel',
#    'athlete_slug': 'marten_van_riel',
#    'athlete_first': 'Marten',
#    'athlete_last': 'Van Riel',
#    'athlete_country_id': 119,
#    'athlete_gender': 'male',
#    'athlete_yob': '1992',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/marten_vanriel_BEL.jpg',
#    'athlete_noc': 'BEL',
#    'athlete_country_name': 'Belgium',
#    'athlete_country_isoa2': 'BE',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/40311/marten_van_riel',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/be.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/40311',
#    'athlete_categories': [42],
#    'points_list_ranking': 6,
#    '_highlightResult': {'athlete_title': {'value': 'Marten Van Riel',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'BEL', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Belgium',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 47630,
#    'athlete_title': 'Gustav Iden',
#    'athlete_slug': 'gustav_iden',
#    'athlete_first': 'Gustav',
#    'athlete_last': 'Iden',
#    'athlete_country_id': 236,
#    'athlete_gender': 'male',
#    'athlete_yob': '1996',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/gustav_iden_NOR.jpg',
#    'athlete_noc': 'NOR',
#    'athlete_country_name': 'Norway',
#    'athlete_country_isoa2': 'NO',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/47630/gustav_iden',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/no.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/47630',
#    'athlete_categories': [42],
#    'points_list_ranking': 7,
#    '_highlightResult': {'athlete_title': {'value': 'Gustav Iden',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'NOR', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Norway',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 5695,
#    'athlete_title': 'Javier Gomez Noya',
#    'athlete_slug': 'javier_gomez_noya',
#    'athlete_first': 'Javier',
#    'athlete_last': 'Gomez Noya',
#    'athlete_country_id': 270,
#    'athlete_gender': 'male',
#    'athlete_yob': '1983',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/Javier_Gomez_Noya_(ESP)_-_Elite20171.JPG',
#    'athlete_noc': 'ESP',
#    'athlete_country_name': 'Spain',
#    'athlete_country_isoa2': 'ES',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/5695/javier_gomez_noya',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/es.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/5695',
#    'athlete_categories': [42],
#    'points_list_ranking': 8,
#    '_highlightResult': {'athlete_title': {'value': 'Javier Gomez Noya',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'ESP', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Spain',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 30433,
#    'athlete_title': 'Henri Schoeman',
#    'athlete_slug': 'henri_schoeman',
#    'athlete_first': 'Henri',
#    'athlete_last': 'Schoeman',
#    'athlete_country_id': 269,
#    'athlete_gender': 'male',
#    'athlete_yob': '1991',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/henri_schoeman_RSA.jpg',
#    'athlete_noc': 'RSA',
#    'athlete_country_name': 'South Africa',
#    'athlete_country_isoa2': 'ZA',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/30433/henri_schoeman',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/za.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/30433',
#    'athlete_categories': [42],
#    'points_list_ranking': 9,
#    '_highlightResult': {'athlete_title': {'value': 'Henri Schoeman',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'RSA', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'South Africa',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 50700,
#    'athlete_title': 'Bence Bicsák',
#    'athlete_slug': 'bence_bicsak',
#    'athlete_first': 'Bence',
#    'athlete_last': 'Bicsák',
#    'athlete_country_id': 182,
#    'athlete_gender': 'male',
#    'athlete_yob': '1995',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/Bence_Dicsak_(HUN)_-_U232017.JPG',
#    'athlete_noc': 'HUN',
#    'athlete_country_name': 'Hungary',
#    'athlete_country_isoa2': 'HU',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/50700/bence_bicsak',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/hu.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/50700',
#    'athlete_categories': [42],
#    'points_list_ranking': 10,
#    '_highlightResult': {'athlete_title': {'value': 'Bence Bicsák',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'HUN', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Hungary',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 41322,
#    'athlete_title': 'Kristian Blummenfelt',
#    'athlete_slug': 'kristian_blummenfelt',
#    'athlete_first': 'Kristian',
#    'athlete_last': 'Blummenfelt',
#    'athlete_country_id': 236,
#    'athlete_gender': 'male',
#    'athlete_yob': '1994',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/kristian_blummenfelt_NOR.jpg',
#    'athlete_noc': 'NOR',
#    'athlete_country_name': 'Norway',
#    'athlete_country_isoa2': 'NO',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/41322/kristian_blummenfelt',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/no.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/41322',
#    'athlete_categories': [42],
#    'points_list_ranking': 11,
#    '_highlightResult': {'athlete_title': {'value': 'Kristian Blummenfelt',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'NOR', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Norway',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 11378,
#    'athlete_title': 'Jonathan Brownlee',
#    'athlete_slug': 'jonathan_brownlee',
#    'athlete_first': 'Jonathan',
#    'athlete_last': 'Brownlee',
#    'athlete_country_id': 292,
#    'athlete_gender': 'male',
#    'athlete_yob': '1990',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/jonny_brownlee_GBR.jpg',
#    'athlete_noc': 'GBR',
#    'athlete_country_name': 'Great Britain',
#    'athlete_country_isoa2': 'GB',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/11378/jonathan_brownlee',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/gb.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/11378',
#    'athlete_categories': [42, 539],
#    'points_list_ranking': 12,
#    '_highlightResult': {'athlete_title': {'value': 'Jonathan Brownlee',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'GBR', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Great Britain',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 39974,
#    'athlete_title': 'Jelle Geens',
#    'athlete_slug': 'jelle_geens',
#    'athlete_first': 'Jelle',
#    'athlete_last': 'Geens',
#    'athlete_country_id': 119,
#    'athlete_gender': 'male',
#    'athlete_yob': '1993',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/jelle_geens_BEL.jpg',
#    'athlete_noc': 'BEL',
#    'athlete_country_name': 'Belgium',
#    'athlete_country_isoa2': 'BE',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/39974/jelle_geens',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/be.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/39974',
#    'athlete_categories': [42],
#    'points_list_ranking': 13,
#    '_highlightResult': {'athlete_title': {'value': 'Jelle Geens',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'BEL', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Belgium',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 104034,
#    'athlete_title': 'Hayden Wilde',
#    'athlete_slug': 'hayden_wilde',
#    'athlete_first': 'Hayden',
#    'athlete_last': 'Wilde',
#    'athlete_country_id': 232,
#    'athlete_gender': 'male',
#    'athlete_yob': '1997',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/hayden_wilde_NZL.jpg',
#    'athlete_noc': 'NZL',
#    'athlete_country_name': 'New Zealand',
#    'athlete_country_isoa2': 'NZ',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/104034/hayden_wilde',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/nz.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/104034',
#    'athlete_categories': [42],
#    'points_list_ranking': 14,
#    '_highlightResult': {'athlete_title': {'value': 'Hayden Wilde',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'NZL', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'New Zealand',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 97196,
#    'athlete_title': 'Matthew McElroy',
#    'athlete_slug': 'matthew_mcelroy',
#    'athlete_first': 'Matthew',
#    'athlete_last': 'McElroy',
#    'athlete_country_id': 293,
#    'athlete_gender': 'male',
#    'athlete_yob': '1992',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/matt_mcelroy_usa.jpg',
#    'athlete_noc': 'USA',
#    'athlete_country_name': 'United States',
#    'athlete_country_isoa2': 'US',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/97196/matthew_mcelroy',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/us.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/97196',
#    'athlete_categories': [42],
#    'points_list_ranking': 15,
#    '_highlightResult': {'athlete_title': {'value': 'Matthew McElroy',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'USA', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'United States',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 30249,
#    'athlete_title': 'Pierre Le Corre',
#    'athlete_slug': 'pierre_le_corre',
#    'athlete_first': 'Pierre',
#    'athlete_last': 'Le Corre',
#    'athlete_country_id': 166,
#    'athlete_gender': 'male',
#    'athlete_yob': '1990',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/45578BB0-159E-4420-B570-E324D108B571.jpeg',
#    'athlete_noc': 'FRA',
#    'athlete_country_name': 'France',
#    'athlete_country_isoa2': 'FR',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/30249/pierre_le_corre',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/fr.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/30249',
#    'athlete_categories': [42],
#    'points_list_ranking': 16,
#    '_highlightResult': {'athlete_title': {'value': 'Pierre Le Corre',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'FRA', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'France',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 123392,
#    'athlete_title': 'Morgan Pearson',
#    'athlete_slug': 'morgan_pearson',
#    'athlete_first': 'Morgan',
#    'athlete_last': 'Pearson',
#    'athlete_country_id': 293,
#    'athlete_gender': 'male',
#    'athlete_yob': '1993',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/morgan_pearson_USA.jpg',
#    'athlete_noc': 'USA',
#    'athlete_country_name': 'United States',
#    'athlete_country_isoa2': 'US',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/123392/morgan_pearson',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/us.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/123392',
#    'athlete_categories': [42],
#    'points_list_ranking': 17,
#    '_highlightResult': {'athlete_title': {'value': 'Morgan Pearson',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'USA', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'United States',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 76434,
#    'athlete_title': 'Casper Stornes',
#    'athlete_slug': 'casper_stornes',
#    'athlete_first': 'Casper',
#    'athlete_last': 'Stornes',
#    'athlete_country_id': 236,
#    'athlete_gender': 'male',
#    'athlete_yob': '1997',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/casper_stornes_NOR.jpg',
#    'athlete_noc': 'NOR',
#    'athlete_country_name': 'Norway',
#    'athlete_country_isoa2': 'NO',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/76434/casper_stornes',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/no.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/76434',
#    'athlete_categories': [42],
#    'points_list_ranking': 18,
#    '_highlightResult': {'athlete_title': {'value': 'Casper Stornes',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'NOR', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Norway',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 67535,
#    'athlete_title': 'Jonas Schomburg',
#    'athlete_slug': 'jonas_schomburg',
#    'athlete_first': 'Jonas',
#    'athlete_last': 'Schomburg',
#    'athlete_country_id': 170,
#    'athlete_gender': 'male',
#    'athlete_yob': '1994',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/jonas_scomburg_ger_elite.jpg',
#    'athlete_noc': 'GER',
#    'athlete_country_name': 'Germany',
#    'athlete_country_isoa2': 'DE',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/67535/jonas_schomburg',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/de.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/67535',
#    'athlete_categories': [42, 539],
#    'points_list_ranking': 19,
#    '_highlightResult': {'athlete_title': {'value': 'Jonas Schomburg',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'GER', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Germany',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 63162,
#    'athlete_title': 'Léo Bergere',
#    'athlete_slug': 'leo_bergere',
#    'athlete_first': 'Léo',
#    'athlete_last': 'Bergere',
#    'athlete_country_id': 166,
#    'athlete_gender': 'male',
#    'athlete_yob': '1996',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/leo_bergere_FRA.jpg',
#    'athlete_noc': 'FRA',
#    'athlete_country_name': 'France',
#    'athlete_country_isoa2': 'FR',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/63162/leo_bergere',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/fr.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/63162',
#    'athlete_categories': [42],
#    'points_list_ranking': 20,
#    '_highlightResult': {'athlete_title': {'value': 'Léo Bergere',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'FRA', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'France',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 49390,
#    'athlete_title': 'Dorian Coninx',
#    'athlete_slug': 'dorian_coninx',
#    'athlete_first': 'Dorian',
#    'athlete_last': 'Coninx',
#    'athlete_country_id': 166,
#    'athlete_gender': 'male',
#    'athlete_yob': '1994',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/dorian_coninx_FRA.jpg',
#    'athlete_noc': 'FRA',
#    'athlete_country_name': 'France',
#    'athlete_country_isoa2': 'FR',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/49390/dorian_coninx',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/fr.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/49390',
#    'athlete_categories': [42],
#    'points_list_ranking': 21,
#    '_highlightResult': {'athlete_title': {'value': 'Dorian Coninx',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'FRA', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'France',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 16392,
#    'athlete_title': 'Richard Murray',
#    'athlete_slug': 'richard_murray',
#    'athlete_first': 'Richard',
#    'athlete_last': 'Murray',
#    'athlete_country_id': 269,
#    'athlete_gender': 'male',
#    'athlete_yob': '1989',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/richard_murray_RSA.jpg',
#    'athlete_noc': 'RSA',
#    'athlete_country_name': 'South Africa',
#    'athlete_country_isoa2': 'ZA',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/16392/richard_murray',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/za.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/16392',
#    'athlete_categories': [42],
#    'points_list_ranking': 22,
#    '_highlightResult': {'athlete_title': {'value': 'Richard Murray',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'RSA', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'South Africa',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 21622,
#    'athlete_title': 'Alois Knabl',
#    'athlete_slug': 'alois_knabl',
#    'athlete_first': 'Alois',
#    'athlete_last': 'Knabl',
#    'athlete_country_id': 112,
#    'athlete_gender': 'male',
#    'athlete_yob': '1992',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/alois_knabl_AUT.jpg',
#    'athlete_noc': 'AUT',
#    'athlete_country_name': 'Austria',
#    'athlete_country_isoa2': 'AT',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/21622/alois_knabl',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/at.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/21622',
#    'athlete_categories': [42, 539],
#    'points_list_ranking': 23,
#    '_highlightResult': {'athlete_title': {'value': 'Alois Knabl',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'AUT', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Austria',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 46686,
#    'athlete_title': 'Sam Ward',
#    'athlete_slug': 'sam_ward',
#    'athlete_first': 'Sam',
#    'athlete_last': 'Ward',
#    'athlete_country_id': 232,
#    'athlete_gender': 'male',
#    'athlete_yob': '1994',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/sam_ward_NZL.jpg',
#    'athlete_noc': 'NZL',
#    'athlete_country_name': 'New Zealand',
#    'athlete_country_isoa2': 'NZ',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/46686/sam_ward',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/nz.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/46686',
#    'athlete_categories': [42],
#    'points_list_ranking': 24,
#    '_highlightResult': {'athlete_title': {'value': 'Sam Ward',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'NZL', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'New Zealand',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 55495,
#    'athlete_title': 'Luke Willian',
#    'athlete_slug': 'luke_willian',
#    'athlete_first': 'Luke',
#    'athlete_last': 'Willian',
#    'athlete_country_id': 111,
#    'athlete_gender': 'male',
#    'athlete_yob': '1996',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/luke_willian_AUS.jpg',
#    'athlete_noc': 'AUS',
#    'athlete_country_name': 'Australia',
#    'athlete_country_isoa2': 'AU',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/55495/luke_willian',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/au.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/55495',
#    'athlete_categories': [42],
#    'points_list_ranking': 25,
#    '_highlightResult': {'athlete_title': {'value': 'Luke Willian',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'AUS', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Australia',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 10536,
#    'athlete_title': 'Joao Pereira',
#    'athlete_slug': 'joao_pereira',
#    'athlete_first': 'Joao',
#    'athlete_last': 'Pereira',
#    'athlete_country_id': 247,
#    'athlete_gender': 'male',
#    'athlete_yob': '1987',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/Triathlon_Portugal_Pereira_Joao_01.jpg',
#    'athlete_noc': 'POR',
#    'athlete_country_name': 'Portugal',
#    'athlete_country_isoa2': 'PT',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/10536/joao_pereira',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/pt.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/10536',
#    'athlete_categories': [42],
#    'points_list_ranking': 26,
#    '_highlightResult': {'athlete_title': {'value': 'Joao Pereira',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'POR', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Portugal',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 10141,
#    'athlete_title': 'Aaron Royle',
#    'athlete_slug': 'aaron_royle',
#    'athlete_first': 'Aaron',
#    'athlete_last': 'Royle',
#    'athlete_country_id': 111,
#    'athlete_gender': 'male',
#    'athlete_yob': '1990',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/aaron_royle_AUS.jpg',
#    'athlete_noc': 'AUS',
#    'athlete_country_name': 'Australia',
#    'athlete_country_isoa2': 'AU',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/10141/aaron_royle',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/au.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/10141',
#    'athlete_categories': [42],
#    'points_list_ranking': 27,
#    '_highlightResult': {'athlete_title': {'value': 'Aaron Royle',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'AUS', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Australia',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 10539,
#    'athlete_title': 'Joao Silva',
#    'athlete_slug': 'joao_silva',
#    'athlete_first': 'Joao',
#    'athlete_last': 'Silva',
#    'athlete_country_id': 247,
#    'athlete_gender': 'male',
#    'athlete_yob': '1989',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/Triathlon_Portugal_Silva_Joao_01.jpg',
#    'athlete_noc': 'POR',
#    'athlete_country_name': 'Portugal',
#    'athlete_country_isoa2': 'PT',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/10539/joao_silva',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/pt.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/10539',
#    'athlete_categories': [42],
#    'points_list_ranking': 28,
#    '_highlightResult': {'athlete_title': {'value': 'Joao Silva',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'POR', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Portugal',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 7503,
#    'athlete_title': 'Crisanto Grajales',
#    'athlete_slug': 'crisanto_grajales',
#    'athlete_first': 'Crisanto',
#    'athlete_last': 'Grajales',
#    'athlete_country_id': 219,
#    'athlete_gender': 'male',
#    'athlete_yob': '1987',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/crisanto_grajales_mex_elite.jpg',
#    'athlete_noc': 'MEX',
#    'athlete_country_name': 'Mexico',
#    'athlete_country_isoa2': 'MX',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/7503/crisanto_grajales',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/mx.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/7503',
#    'athlete_categories': [42],
#    'points_list_ranking': 29,
#    '_highlightResult': {'athlete_title': {'value': 'Crisanto Grajales',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'MEX', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Mexico',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 46198,
#    'athlete_title': 'Eli Hemming',
#    'athlete_slug': 'eli_hemming',
#    'athlete_first': 'Eli',
#    'athlete_last': 'Hemming',
#    'athlete_country_id': 293,
#    'athlete_gender': 'male',
#    'athlete_yob': '1995',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/eli_hemmings_USA.jpg',
#    'athlete_noc': 'USA',
#    'athlete_country_name': 'United States',
#    'athlete_country_isoa2': 'US',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/46198/eli_hemming',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/us.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/46198',
#    'athlete_categories': [42],
#    'points_list_ranking': 30,
#    '_highlightResult': {'athlete_title': {'value': 'Eli Hemming',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'USA', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'United States',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 70032,
#    'athlete_title': 'Max Studer',
#    'athlete_slug': 'max_studer',
#    'athlete_first': 'Max',
#    'athlete_last': 'Studer',
#    'athlete_country_id': 276,
#    'athlete_gender': 'male',
#    'athlete_yob': '1996',
#    'validated': False,
#    'athlete_profile_image': None,
#    'athlete_noc': 'SUI',
#    'athlete_country_name': 'Switzerland',
#    'athlete_country_isoa2': 'CH',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/70032/max_studer',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/ch.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/70032',
#    'athlete_categories': [42],
#    'points_list_ranking': 31,
#    '_highlightResult': {'athlete_title': {'value': 'Max Studer',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'SUI', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Switzerland',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 18714,
#    'athlete_title': 'Kevin McDowell',
#    'athlete_slug': 'kevin_mcdowell',
#    'athlete_first': 'Kevin',
#    'athlete_last': 'McDowell',
#    'athlete_country_id': 293,
#    'athlete_gender': 'male',
#    'athlete_yob': '1992',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/Kevin_McDowell_(USA)_olympics_headshots_WA8_2327.jpg',
#    'athlete_noc': 'USA',
#    'athlete_country_name': 'United States',
#    'athlete_country_isoa2': 'US',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/18714/kevin_mcdowell',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/us.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/18714',
#    'athlete_categories': [42],
#    'points_list_ranking': 32,
#    '_highlightResult': {'athlete_title': {'value': 'Kevin McDowell',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'USA', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'United States',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 11162,
#    'athlete_title': 'Rostislav Pevtsov',
#    'athlete_slug': 'rostislav_pevtsov',
#    'athlete_first': 'Rostislav',
#    'athlete_last': 'Pevtsov',
#    'athlete_country_id': 113,
#    'athlete_gender': 'male',
#    'athlete_yob': '1987',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/2017wtsgrandfinal_rotterdam_124551_wag2291.JPG',
#    'athlete_noc': 'AZE',
#    'athlete_country_name': 'Azerbaijan',
#    'athlete_country_isoa2': 'AZ',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/11162/rostislav_pevtsov',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/az.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/11162',
#    'athlete_categories': [42],
#    'points_list_ranking': 33,
#    '_highlightResult': {'athlete_title': {'value': 'Rostislav Pevtsov',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'AZE', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Azerbaijan',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 63428,
#    'athlete_title': 'Antonio Serrat Seoane',
#    'athlete_slug': 'antonio_serrat_seoane',
#    'athlete_first': 'Antonio',
#    'athlete_last': 'Serrat Seoane',
#    'athlete_country_id': 270,
#    'athlete_gender': 'male',
#    'athlete_yob': '1995',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/antonio_serrat_seoane_ESP.jpg',
#    'athlete_noc': 'ESP',
#    'athlete_country_name': 'Spain',
#    'athlete_country_isoa2': 'ES',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/63428/antonio_serrat_seoane',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/es.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/63428',
#    'athlete_categories': [42],
#    'points_list_ranking': 34,
#    '_highlightResult': {'athlete_title': {'value': 'Antonio Serrat Seoane',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'ESP', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Spain',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 12773,
#    'athlete_title': 'Rodrigo Gonzalez',
#    'athlete_slug': 'rodrigo_gonzalez',
#    'athlete_first': 'Rodrigo',
#    'athlete_last': 'Gonzalez',
#    'athlete_country_id': 219,
#    'athlete_gender': 'male',
#    'athlete_yob': '1989',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/rodrigo_gonzalez_mex_elite.jpg',
#    'athlete_noc': 'MEX',
#    'athlete_country_name': 'Mexico',
#    'athlete_country_isoa2': 'MX',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/12773/rodrigo_gonzalez',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/mx.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/12773',
#    'athlete_categories': [42],
#    'points_list_ranking': 35,
#    '_highlightResult': {'athlete_title': {'value': 'Rodrigo Gonzalez',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'MEX', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Mexico',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 96742,
#    'athlete_title': 'Alex Yee',
#    'athlete_slug': 'alex_yee',
#    'athlete_first': 'Alex',
#    'athlete_last': 'Yee',
#    'athlete_country_id': 292,
#    'athlete_gender': 'male',
#    'athlete_yob': '1998',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/alex_yee_GBR.jpg',
#    'athlete_noc': 'GBR',
#    'athlete_country_name': 'Great Britain',
#    'athlete_country_isoa2': 'GB',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/96742/alex_yee',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/gb.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/96742',
#    'athlete_categories': [42],
#    'points_list_ranking': 36,
#    '_highlightResult': {'athlete_title': {'value': 'Alex Yee',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'GBR', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Great Britain',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 28500,
#    'athlete_title': 'Ryan Bailie',
#    'athlete_slug': 'ryan_bailie',
#    'athlete_first': 'Ryan',
#    'athlete_last': 'Bailie',
#    'athlete_country_id': 111,
#    'athlete_gender': 'male',
#    'athlete_yob': '1990',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/ryan_baillie_AUS.jpg',
#    'athlete_noc': 'AUS',
#    'athlete_country_name': 'Australia',
#    'athlete_country_isoa2': 'AU',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/28500/ryan_bailie',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/au.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/28500',
#    'athlete_categories': [42],
#    'points_list_ranking': 37,
#    '_highlightResult': {'athlete_title': {'value': 'Ryan Bailie',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'AUS', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Australia',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 41060,
#    'athlete_title': 'Justus Nieschlag',
#    'athlete_slug': 'justus_nieschlag',
#    'athlete_first': 'Justus',
#    'athlete_last': 'Nieschlag',
#    'athlete_country_id': 170,
#    'athlete_gender': 'male',
#    'athlete_yob': '1992',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/justus_nieschlagg_ger_elite.jpg',
#    'athlete_noc': 'GER',
#    'athlete_country_name': 'Germany',
#    'athlete_country_isoa2': 'DE',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/41060/justus_nieschlag',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/de.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/41060',
#    'athlete_categories': [42],
#    'points_list_ranking': 38,
#    '_highlightResult': {'athlete_title': {'value': 'Justus Nieschlag',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'GER', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Germany',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 23656,
#    'athlete_title': 'Felix Duchampt',
#    'athlete_slug': 'felix_duchampt',
#    'athlete_first': 'Felix',
#    'athlete_last': 'Duchampt',
#    'athlete_country_id': 250,
#    'athlete_gender': 'male',
#    'athlete_yob': '1989',
#    'validated': False,
#    'athlete_profile_image': None,
#    'athlete_noc': 'ROU',
#    'athlete_country_name': 'Romania',
#    'athlete_country_isoa2': 'RO',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/23656/felix_duchampt',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/ro.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/23656',
#    'athlete_categories': [42],
#    'points_list_ranking': 39,
#    '_highlightResult': {'athlete_title': {'value': 'Felix Duchampt',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'ROU', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Romania',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 6186,
#    'athlete_title': 'Irving Perez',
#    'athlete_slug': 'irving_perez',
#    'athlete_first': 'Irving',
#    'athlete_last': 'Perez',
#    'athlete_country_id': 219,
#    'athlete_gender': 'male',
#    'athlete_yob': '1986',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/irving_perez_mex_elite.jpg',
#    'athlete_noc': 'MEX',
#    'athlete_country_name': 'Mexico',
#    'athlete_country_isoa2': 'MX',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/6186/irving_perez',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/mx.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/6186',
#    'athlete_categories': [42],
#    'points_list_ranking': 40,
#    '_highlightResult': {'athlete_title': {'value': 'Irving Perez',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'MEX', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Mexico',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 39836,
#    'athlete_title': 'Simon Viain',
#    'athlete_slug': 'simon_viain',
#    'athlete_first': 'Simon',
#    'athlete_last': 'Viain',
#    'athlete_country_id': 166,
#    'athlete_gender': 'male',
#    'athlete_yob': '1993',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/Simon_Vlain_(FRA)_-_Elite2017.JPG',
#    'athlete_noc': 'FRA',
#    'athlete_country_name': 'France',
#    'athlete_country_isoa2': 'FR',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/39836/simon_viain',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/fr.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/39836',
#    'athlete_categories': [42],
#    'points_list_ranking': 41,
#    '_highlightResult': {'athlete_title': {'value': 'Simon Viain',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'FRA', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'France',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 88205,
#    'athlete_title': 'Samuel Dickinson',
#    'athlete_slug': 'samuel_dickinson',
#    'athlete_first': 'Samuel',
#    'athlete_last': 'Dickinson',
#    'athlete_country_id': 292,
#    'athlete_gender': 'male',
#    'athlete_yob': '1997',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/sam-dickinson_GBR.jpg',
#    'athlete_noc': 'GBR',
#    'athlete_country_name': 'Great Britain',
#    'athlete_country_isoa2': 'GB',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/88205/samuel_dickinson',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/gb.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/88205',
#    'athlete_categories': [42],
#    'points_list_ranking': 42,
#    '_highlightResult': {'athlete_title': {'value': 'Samuel Dickinson',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'GBR', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Great Britain',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 98547,
#    'athlete_title': 'Takumi Hojo',
#    'athlete_slug': 'takumi_hojo',
#    'athlete_first': 'Takumi',
#    'athlete_last': 'Hojo',
#    'athlete_country_id': 192,
#    'athlete_gender': 'male',
#    'athlete_yob': '1996',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/takami_hojo_jpn.jpg',
#    'athlete_noc': 'JPN',
#    'athlete_country_name': 'Japan',
#    'athlete_country_isoa2': 'JP',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/98547/takumi_hojo',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/jp.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/98547',
#    'athlete_categories': [42],
#    'points_list_ranking': 43,
#    '_highlightResult': {'athlete_title': {'value': 'Takumi Hojo',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'JPN', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Japan',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 80795,
#    'athlete_title': 'Matthew Hauser',
#    'athlete_slug': 'matthew_hauser',
#    'athlete_first': 'Matthew',
#    'athlete_last': 'Hauser',
#    'athlete_country_id': 111,
#    'athlete_gender': 'male',
#    'athlete_yob': '1998',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/Matt_Hauser_(AUS)_-_JR2017.JPG',
#    'athlete_noc': 'AUS',
#    'athlete_country_name': 'Australia',
#    'athlete_country_isoa2': 'AU',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/80795/matthew_hauser',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/au.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/80795',
#    'athlete_categories': [42],
#    'points_list_ranking': 44,
#    '_highlightResult': {'athlete_title': {'value': 'Matthew Hauser',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'AUS', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Australia',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 69143,
#    'athlete_title': 'Manoel Messias',
#    'athlete_slug': 'manoel_messias',
#    'athlete_first': 'Manoel',
#    'athlete_last': 'Messias',
#    'athlete_country_id': 127,
#    'athlete_gender': 'male',
#    'athlete_yob': '1996',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/Manoel_Messias_(BRA)_-_U232017.JPG',
#    'athlete_noc': 'BRA',
#    'athlete_country_name': 'Brazil',
#    'athlete_country_isoa2': 'BR',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/69143/manoel_messias',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/br.png',
# ...
#    'athlete_country_name': 'Ireland',
#    'athlete_country_isoa2': 'IE',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/46674/constantine_doherty',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/ie.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/46674',
#    'athlete_categories': [42],
#    'points_list_ranking': 86,
#    '_highlightResult': {'athlete_title': {'value': 'Constantine Doherty',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'IRL', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Ireland',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 85863,
#    'athlete_title': 'Badr Siwane',
#    'athlete_slug': 'badr_siwane',
#    'athlete_first': 'Badr',
#    'athlete_last': 'Siwane',
#    'athlete_country_id': 224,
#    'athlete_gender': 'male',
#    'athlete_yob': '1994',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/badr_siwane.jpg',
#    'athlete_noc': 'MAR',
#    'athlete_country_name': 'Morocco',
#    'athlete_country_isoa2': 'MA',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/85863/badr_siwane',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/ma.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/85863',
#    'athlete_categories': [42],
#    'points_list_ranking': 87,
#    '_highlightResult': {'athlete_title': {'value': 'Badr Siwane',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'MAR', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Morocco',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 40710,
#    'athlete_title': 'Russell White',
#    'athlete_slug': 'russell_white',
#    'athlete_first': 'Russell',
#    'athlete_last': 'White',
#    'athlete_country_id': 188,
#    'athlete_gender': 'male',
#    'athlete_yob': '1992',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/russel_white_IRL1.jpg',
#    'athlete_noc': 'IRL',
#    'athlete_country_name': 'Ireland',
#    'athlete_country_isoa2': 'IE',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/40710/russell_white',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/ie.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/40710',
#    'athlete_categories': [42],
#    'points_list_ranking': 88,
#    '_highlightResult': {'athlete_title': {'value': 'Russell White',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'IRL', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Ireland',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 47611,
#    'athlete_title': 'Genis Grau',
#    'athlete_slug': 'genis_grau',
#    'athlete_first': 'Genis',
#    'athlete_last': 'Grau',
#    'athlete_country_id': 270,
#    'athlete_gender': 'male',
#    'athlete_yob': '1994',
#    'validated': False,
#    'athlete_profile_image': None,
#    'athlete_noc': 'ESP',
#    'athlete_country_name': 'Spain',
#    'athlete_country_isoa2': 'ES',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/47611/genis_grau',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/es.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/47611',
#    'athlete_categories': [42],
#    'points_list_ranking': 89,
#    '_highlightResult': {'athlete_title': {'value': 'Genis Grau',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'ESP', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Spain',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 6707,
#    'athlete_title': 'Jan Celustka',
#    'athlete_slug': 'jan_celustka',
#    'athlete_first': 'Jan',
#    'athlete_last': 'Celustka',
#    'athlete_country_id': 152,
#    'athlete_gender': 'male',
#    'athlete_yob': '1982',
#    'validated': False,
#    'athlete_profile_image': None,
#    'athlete_noc': 'CZE',
#    'athlete_country_name': 'Czech Republic',
#    'athlete_country_isoa2': 'CZ',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/6707/jan_celustka',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/cz.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/6707',
#    'athlete_categories': [42],
#    'points_list_ranking': 90,
#    '_highlightResult': {'athlete_title': {'value': 'Jan Celustka',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'CZE', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Czech Republic',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 79706,
#    'athlete_title': 'Charles Paquet',
#    'athlete_slug': 'charles_paquet',
#    'athlete_first': 'Charles',
#    'athlete_last': 'Paquet',
#    'athlete_country_id': 135,
#    'athlete_gender': 'male',
#    'athlete_yob': '1997',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/charles_pacquet_can_u23.jpg',
#    'athlete_noc': 'CAN',
#    'athlete_country_name': 'Canada',
#    'athlete_country_isoa2': 'CA',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/79706/charles_paquet',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/ca.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/79706',
#    'athlete_categories': [42],
#    'points_list_ranking': 91,
#    '_highlightResult': {'athlete_title': {'value': 'Charles Paquet',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'CAN', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Canada',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 11001,
#    'athlete_title': 'Gábor Faldum',
#    'athlete_slug': 'gabor_faldum',
#    'athlete_first': 'Gábor',
#    'athlete_last': 'Faldum',
#    'athlete_country_id': 182,
#    'athlete_gender': 'male',
#    'athlete_yob': '1988',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/gabor_faldum_HUN.jpg',
#    'athlete_noc': 'HUN',
#    'athlete_country_name': 'Hungary',
#    'athlete_country_isoa2': 'HU',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/11001/gabor_faldum',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/hu.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/11001',
#    'athlete_categories': [42],
#    'points_list_ranking': 92,
#    '_highlightResult': {'athlete_title': {'value': 'Gábor Faldum',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'HUN', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Hungary',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 47796,
#    'athlete_title': 'Ilya Prasolov',
#    'athlete_slug': 'ilya_prasolov',
#    'athlete_first': 'Ilya',
#    'athlete_last': 'Prasolov',
#    'athlete_country_id': 251,
#    'athlete_gender': 'male',
#    'athlete_yob': '1994',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/Ilya_Prasolov_(RUS)_-_U232017.JPG',
#    'athlete_noc': 'RUS',
#    'athlete_country_name': 'Russia',
#    'athlete_country_isoa2': 'RU',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/47796/ilya_prasolov',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/ru.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/47796',
#    'athlete_categories': [42],
#    'points_list_ranking': 93,
#    '_highlightResult': {'athlete_title': {'value': 'Ilya Prasolov',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'RUS', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Russia',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 17069,
#    'athlete_title': 'Luciano Taccone',
#    'athlete_slug': 'luciano_taccone',
#    'athlete_first': 'Luciano',
#    'athlete_last': 'Taccone',
#    'athlete_country_id': 108,
#    'athlete_gender': 'male',
#    'athlete_yob': '1989',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/Triathlon_Argentina_Taccone_Lucciano_02.jpg',
#    'athlete_noc': 'ARG',
#    'athlete_country_name': 'Argentina',
#    'athlete_country_isoa2': 'AR',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/17069/luciano_taccone',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/ar.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/17069',
#    'athlete_categories': [42],
#    'points_list_ranking': 94,
#    '_highlightResult': {'athlete_title': {'value': 'Luciano Taccone',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'ARG', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Argentina',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 39908,
#    'athlete_title': 'Vicente Hernandez',
#    'athlete_slug': 'vicente_hernandez',
#    'athlete_first': 'Vicente',
#    'athlete_last': 'Hernandez',
#    'athlete_country_id': 270,
#    'athlete_gender': 'male',
#    'athlete_yob': '1991',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/vicente_hernandez_ESP.jpg',
#    'athlete_noc': 'ESP',
#    'athlete_country_name': 'Spain',
#    'athlete_country_isoa2': 'ES',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/39908/vicente_hernandez',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/es.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/39908',
#    'athlete_categories': [42],
#    'points_list_ranking': 95,
#    '_highlightResult': {'athlete_title': {'value': 'Vicente Hernandez',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'ESP', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Spain',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 80630,
#    'athlete_title': 'Jason West',
#    'athlete_slug': 'jason_west',
#    'athlete_first': 'Jason',
#    'athlete_last': 'West',
#    'athlete_country_id': 293,
#    'athlete_gender': 'male',
#    'athlete_yob': '1993',
#    'validated': False,
#    'athlete_profile_image': None,
#    'athlete_noc': 'USA',
#    'athlete_country_name': 'United States',
#    'athlete_country_isoa2': 'US',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/80630/jason_west',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/us.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/80630',
#    'athlete_categories': [42],
#    'points_list_ranking': 96,
#    '_highlightResult': {'athlete_title': {'value': 'Jason West',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'USA', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'United States',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 90031,
#    'athlete_title': 'Ren Sato',
#    'athlete_slug': 'ren_sato',
#    'athlete_first': 'Ren',
#    'athlete_last': 'Sato',
#    'athlete_country_id': 192,
#    'athlete_gender': 'male',
#    'athlete_yob': '1995',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/rei_sato_JPN.jpg',
#    'athlete_noc': 'JPN',
#    'athlete_country_name': 'Japan',
#    'athlete_country_isoa2': 'JP',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/90031/ren_sato',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/jp.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/90031',
#    'athlete_categories': [42],
#    'points_list_ranking': 97,
#    '_highlightResult': {'athlete_title': {'value': 'Ren Sato',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'JPN', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Japan',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 17043,
#    'athlete_title': 'Ben Kanute',
#    'athlete_slug': 'ben_kanute',
#    'athlete_first': 'Ben',
#    'athlete_last': 'Kanute',
#    'athlete_country_id': 293,
#    'athlete_gender': 'male',
#    'athlete_yob': '1992',
#    'validated': True,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/Ben_Kanute_(USA)_-_Elite2017.JPG',
#    'athlete_noc': 'USA',
#    'athlete_country_name': 'United States',
#    'athlete_country_isoa2': 'US',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/17043/ben_kanute',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/us.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/17043',
#    'athlete_categories': [42],
#    'points_list_ranking': 98,
#    '_highlightResult': {'athlete_title': {'value': 'Ben Kanute',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'USA', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'United States',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 74419,
#    'athlete_title': 'Alberto Gonzalez Garcia',
#    'athlete_slug': 'alberto_gonzalez_garcia',
#    'athlete_first': 'Alberto',
#    'athlete_last': 'Gonzalez Garcia',
#    'athlete_country_id': 270,
#    'athlete_gender': 'male',
#    'athlete_yob': '1998',
#    'validated': True,
#    'athlete_profile_image': None,
#    'athlete_noc': 'ESP',
#    'athlete_country_name': 'Spain',
#    'athlete_country_isoa2': 'ES',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/74419/alberto_gonzalez_garcia',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/es.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/74419',
#    'athlete_categories': [42],
#    'points_list_ranking': 99,
#    '_highlightResult': {'athlete_title': {'value': 'Alberto Gonzalez Garcia',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'ESP', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Spain',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'athlete_id': 16522,
#    'athlete_title': 'Felipe Barraza',
#    'athlete_slug': 'felipe_barraza',
#    'athlete_first': 'Felipe',
#    'athlete_last': 'Barraza',
#    'athlete_country_id': 140,
#    'athlete_gender': 'male',
#    'athlete_yob': '1991',
#    'validated': False,
#    'athlete_profile_image': 'http://www.triathlon.org/images/athlete_thumbs/felipe_barraza.jpg',
#    'athlete_noc': 'CHI',
#    'athlete_country_name': 'Chile',
#    'athlete_country_isoa2': 'CL',
#    'athlete_listing': 'https://www.triathlon.org/athletes/profile/16522/felipe_barraza',
#    'athlete_flag': 'https://triathlon-images.imgix.net/images/icons/cl.png',
#    'athlete_api_listing': 'https://api.triathlon.org/v1/v1/athletes/16522',
#    'athlete_categories': [42],
#    'points_list_ranking': 100,
#    '_highlightResult': {'athlete_title': {'value': 'Felipe Barraza',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'athlete_noc': {'value': 'CHI', 'matchLevel': 'none', 'matchedWords': []},
#     'athlete_country_name': {'value': 'Chile',
#      'matchLevel': 'none',
#      'matchedWords': []}}}],
#  'first_page_url': 'https://api.triathlon.org/v1/search?per_page=100&collection=athletes&filters=athlete_gender%2Cmale%7Celite%2Ctrue&page=1',
#  'from': 1,
#  'last_page': 10,
#  'last_page_url': 'https://api.triathlon.org/v1/search?per_page=100&collection=athletes&filters=athlete_gender%2Cmale%7Celite%2Ctrue&page=10',
#  'next_page_url': 'https://api.triathlon.org/v1/search?per_page=100&collection=athletes&filters=athlete_gender%2Cmale%7Celite%2Ctrue&page=2',
#  'path': 'https://api.triathlon.org/v1/search',
#  'per_page': '100',
#  'prev_page_url': None,
#  'to': 100,
#  'total': 1000}

# %%
os.system('say -v Samantha successful response')
time.sleep(2)

# %%
dic_athlete_id = json_normalize(response.get("data"))
dic_athlete_id
# Out:
#     athlete_id            athlete_title             athlete_slug  \
# 0        11143             Vincent Luis             vincent_luis
# 1        11402               Mario Mola               mario_mola
# 2        29442          Fernando Alarza          fernando_alarza
# 3        45915        Jacob Birtwhistle        jacob_birtwhistle
# 4        49411         Tyler Mislawchuk         tyler_mislawchuk
# ..         ...                      ...                      ...
# 95       80630               Jason West               jason_west
# 96       90031                 Ren Sato                 ren_sato
# 97       17043               Ben Kanute               ben_kanute
# 98       74419  Alberto Gonzalez Garcia  alberto_gonzalez_garcia
# 99       16522           Felipe Barraza           felipe_barraza
#
#    athlete_first     athlete_last  athlete_country_id athlete_gender  \
# 0        Vincent             Luis                 166           male
# 1          Mario             Mola                 270           male
# 2       Fernando           Alarza                 270           male
# 3          Jacob      Birtwhistle                 111           male
# 4          Tyler       Mislawchuk                 135           male
# ..           ...              ...                 ...            ...
# 95         Jason             West                 293           male
# 96           Ren             Sato                 192           male
# 97           Ben           Kanute                 293           male
# 98       Alberto  Gonzalez Garcia                 270           male
# 99        Felipe          Barraza                 140           male
#
#    athlete_yob  validated                              athlete_profile_image  \
# 0         1989       True  http://www.triathlon.org/images/athlete_thumbs...
# 1         1990       True  http://www.triathlon.org/images/athlete_thumbs...
# 2         1991       True  http://www.triathlon.org/images/athlete_thumbs...
# 3         1995      False  http://www.triathlon.org/images/athlete_thumbs...
# 4         1994       True  http://www.triathlon.org/images/athlete_thumbs...
# ..         ...        ...                                                ...
# 95        1993      False                                               None
# 96        1995      False  http://www.triathlon.org/images/athlete_thumbs...
# 97        1992       True  http://www.triathlon.org/images/athlete_thumbs...
# 98        1998       True                                               None
# 99        1991      False  http://www.triathlon.org/images/athlete_thumbs...
#
#     ... points_list_ranking _highlightResult.athlete_title.value  \
# 0   ...                   1                         Vincent Luis
# 1   ...                   2                           Mario Mola
# 2   ...                   3                      Fernando Alarza
# 3   ...                   4                    Jacob Birtwhistle
# 4   ...                   5                     Tyler Mislawchuk
# ..  ...                 ...                                  ...
# 95  ...                  96                           Jason West
# 96  ...                  97                             Ren Sato
# 97  ...                  98                           Ben Kanute
# 98  ...                  99              Alberto Gonzalez Garcia
# 99  ...                 100                       Felipe Barraza
#
#    _highlightResult.athlete_title.matchLevel  \
# 0                                       none
# 1                                       none
# 2                                       none
# 3                                       none
# 4                                       none
# ..                                       ...
# 95                                      none
# 96                                      none
# 97                                      none
# 98                                      none
# 99                                      none
#
#    _highlightResult.athlete_title.matchedWords  \
# 0                                           []
# 1                                           []
# 2                                           []
# 3                                           []
# 4                                           []
# ..                                         ...
# 95                                          []
# 96                                          []
# 97                                          []
# 98                                          []
# 99                                          []
#
#    _highlightResult.athlete_noc.value _highlightResult.athlete_noc.matchLevel  \
# 0                                 FRA                                    none
# 1                                 ESP                                    none
# 2                                 ESP                                    none
# 3                                 AUS                                    none
# 4                                 CAN                                    none
# ..                                ...                                     ...
# 95                                USA                                    none
# 96                                JPN                                    none
# 97                                USA                                    none
# 98                                ESP                                    none
# 99                                CHI                                    none
#
#    _highlightResult.athlete_noc.matchedWords  \
# 0                                         []
# 1                                         []
# 2                                         []
# 3                                         []
# 4                                         []
# ..                                       ...
# 95                                        []
# 96                                        []
# 97                                        []
# 98                                        []
# 99                                        []
#
#     _highlightResult.athlete_country_name.value  \
# 0                                        France
# 1                                         Spain
# 2                                         Spain
# 3                                     Australia
# 4                                        Canada
# ..                                          ...
# 95                                United States
# 96                                        Japan
# 97                                United States
# 98                                        Spain
# 99                                        Chile
#
#    _highlightResult.athlete_country_name.matchLevel  \
# 0                                              none
# 1                                              none
# 2                                              none
# 3                                              none
# 4                                              none
# ..                                              ...
# 95                                             none
# 96                                             none
# 97                                             none
# 98                                             none
# 99                                             none
#
#    _highlightResult.athlete_country_name.matchedWords
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
# [100 rows x 27 columns]

# %%
lista_id = list(dic_athlete_id["athlete_id"])

# %%
os.system('say -v Samantha creating url')
time.sleep(2)

# %%
url_lista = funcion.web_atleta(lista_id)

# %%
os.system('say -v Samantha successful url')
time.sleep(2)

# %% [markdown]
# Listas de las columnas a usar

# %%
lista_name = []
lista_stats = []
lista_weight = []
lista_height = []
lista_sponsors = []
lista_twitter = []
lista_place_of_birth = []
lista_languages_spoken = []

# %%
os.system('say -v Samantha calling second Api')
# Out:
# 0

# %% [markdown]
# Llamamos a la api para que baje la información de cada atleta

# %%
for i in url_lista:
    url = i

    headers = {"apikey": api_key}

    response = requests.request("GET", url, headers=headers).json()
    lista_stats.append(response.get("data")["stats"])
    lista_name.append(response.get("data")["athlete_title"])
    lista_weight.append(response.get("data")["weight"])
    lista_height.append(response.get("data")["height"])
    lista_sponsors.append(response.get("data")["sponsors"])
    lista_twitter.append(response.get("data")["twitter"])
    lista_place_of_birth.append(response.get("data")["place_of_birth"])
    lista_languages_spoken.append(response.get("data")["languages_spoken"])

# %%
os.system('say -v Samantha successful response')
time.sleep(1.5)

# %%
os.system('say -v Samantha creating dataframes')
time.sleep(1.5)

# %% [markdown]
# Convertir listas en dataframes

# %%
df_stats = pd.DataFrame(lista_stats)
df_name = pd.DataFrame(lista_name)
df_weight = pd.DataFrame(lista_weight)
df_height = pd.DataFrame(lista_height)
df_sponsors = pd.DataFrame(lista_sponsors)
df_twitter = pd.DataFrame(lista_twitter)
df_place_of_birth = pd.DataFrame(lista_place_of_birth)
df_languages_spoken = pd.DataFrame(lista_languages_spoken)

# %% [markdown]
# Renombrar columnas

# %%
df_name.columns = ["Name"]
df_sponsors.columns = ["Sponsors"]
df_height.columns = ["Height"]
df_weight.columns = ["Weight"]
df_languages_spoken.columns = ["Languages"]
df_place_of_birth.columns = ["Place_of_birth"]
df_twitter.columns = ["Twitter"]

# %%
os.system('say -v Samantha joining dataframes')
time.sleep(1.5)

# %% [markdown]
# Unir todos los dataframes

# %%
df_outer = df_name.join(df_height, how= "outer")
df_outer = df_outer.join(df_weight, how= "outer")
df_outer = df_outer.join(df_languages_spoken, how= "outer")
df_outer = df_outer.join(df_sponsors, how= "outer")
df_outer = df_outer.join(df_twitter, how= "outer")
df_outer = df_outer.join(df_stats, how= "outer")

# %% [markdown]
# Eliminamos unidades de media y renombramos algunos valores

# %%
df_outer["Height"] = df_outer["Height"].str.rstrip("cm")
df_outer["Height"] = df_outer["Height"].str.rstrip(" cm")
df_outer["Weight"] = df_outer["Weight"].str.rstrip("kg")
df_outer["Weight"] = df_outer["Weight"].replace({'None of your bu': None, '70 kg “in season “ ;-)': 70,'None of your business ': None})
df_outer["race_podium_percentage"] = df_outer["race_podium_percentage"].astype(int)

# %%
df = pd.read_excel('data/WorldRankingsEliteMen.xlsx')

# %%
df = df[['Rank','name','YOB', 'Country', 'Total Points']]

# %%
df_total = df.join(df_outer, how = "outer")
df_total = df_total[['Rank', 'name', 'YOB', 'Country', 'Total Points',
       'Height', 'Weight', 'Languages', 'Sponsors', 'Twitter', 'race_starts',
       'race_finishes', 'finish_percentage', 'race_wins', 'race_podiums',
       'race_podium_percentage']]
df_total = df_total[df_total.Height != "Unknown"]
df_total = df_total[df_total.Weight != "Unknown"]
df_total["race_wins_percentage"] = ((df_total["race_wins"] / df_total["race_starts"])* 100).round()
df_total["Agebucket"] = pd.cut(df_total.YOB, bins=[1982,1985,1988,1991, 1994, 1997,2000])
df_total[["Height", "Weight"]] = df_total[["Height", "Weight"]].apply(pd.to_numeric)

# %%
df_total

# %%
os.system('say -v Samantha exporting dataframe as triathlon_merge')

# %%
df_total.to_csv("data/triatlon_merge.csv")
